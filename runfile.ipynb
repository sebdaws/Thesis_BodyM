# %%
# %run test_deeplabv3.py --mode test --weights mobilenet
# Out:
# Task: test deeplabv3
# Initialising dataset...
# Data ready.
# Device: cuda
# Loading model...
# Downloading: "https://download.pytorch.org/models/deeplabv3_mobilenet_v3_large-fc3c493d.pth" to C:\Users\Sebastian/.cache\torch\hub\checkpoints\deeplabv3_mobilenet_v3_large-fc3c493d.pth
# 100%|██████████| 42.3M/42.3M [00:19<00:00, 2.24MB/s]
# Model loaded
# Testing deeplabv3 with mobilenet, 478 test samples, on cuda
# Processed 4/478 - Current IoU: 0.7577
# Processed 8/478 - Current IoU: 0.7593
# Processed 12/478 - Current IoU: 0.9006
# Processed 16/478 - Current IoU: 0.8917
# Processed 20/478 - Current IoU: 0.9077
# Processed 24/478 - Current IoU: 0.8980
# Processed 28/478 - Current IoU: 0.7835
# Processed 32/478 - Current IoU: 0.8743
# Processed 36/478 - Current IoU: 0.8482
# Processed 40/478 - Current IoU: 0.8092
# Processed 44/478 - Current IoU: 0.5441
# Processed 48/478 - Current IoU: 0.5706
# Processed 52/478 - Current IoU: 0.7920
# Processed 56/478 - Current IoU: 0.6988
# ...

# %%
# %run test_deeplabv3.py --mode train --percent 0.1 --weights mobilenet
# Out:
# Task: train deeplabv3, 10% of training set, 20 epochs
# Initialising dataset...
# Data ready.
# Device: cuda
# Loading model...
# Model loaded
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# File ~\Documents\University College London\Project\test_deeplabv3.py:182
#     179         raise AttributeError("Incorrect mode, should be 'train'or 'test'")
#     181 if __name__ == '__main__':
# --> 182     main()
#
# File ~\Documents\University College London\Project\test_deeplabv3.py:163, in main()
#     160 if args.mode == 'train':
#     161     optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# --> 163     train_model(model, device, train_loader, optimizer, num_epochs=args.num_epochs)
#     164     if not os.path.exists('trained_models'):
#     165         os.mkdir('trained_models')
#
# ...
