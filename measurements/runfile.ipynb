# %%
# %run trainer.py
# Out:
# Using device: cpu
# Inputs of shape torch.Size([8, 4, 640, 960])
# Batch 20/239, Loss: 493021.0891
# NaNs found in targets 32
# Batch 40/239, Loss: 453769.5000
# NaNs found in targets 49
# Batch 60/239, Loss: 422108.7125
# Batch 80/239, Loss: 397483.1156
# Batch 100/239, Loss: 353627.2719
# NaNs found in targets 107
# NaNs found in targets 108
# Batch 120/239, Loss: 261474.7531
# NaNs found in targets 129
# Batch 140/239, Loss: 211104.4125
# NaNs found in targets 147
# Batch 160/239, Loss: 164049.5609
# Batch 180/239, Loss: 123664.5945
# NaNs found in targets 190
# Batch 200/239, Loss: 77611.5051
# Batch 220/239, Loss: 45685.8920
# NaNs found in targets 221
# Epoch 1, Loss: 253409.5730
# Validation Loss: 88289419.2000
# NaNs found in targets 2
# Batch 20/239, Loss: 12811.0978
# Batch 40/239, Loss: 11335.2268
# NaNs found in targets 57
# Batch 60/239, Loss: 8456.6890
# Batch 80/239, Loss: 8027.2729
# NaNs found in targets 82
# Batch 100/239, Loss: 7611.7072
# ...
